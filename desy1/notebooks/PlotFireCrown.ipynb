# %%
import numpy as np
import sacc
import matplotlib.pyplot as plt

# %%
ANALYSIS_ID = 'a26bdec0920240b8909b97e39c898d95'

# %%
chain = np.loadtxt(f'../configs/output_{ANALYSIS_ID}/chain.txt')

# %%
omega_m = chain[:,[0]]+0.0485

# %%
sigma_8 = chain[:,[1]]

# %%
import pandas as pd
import corner

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(8, 8))
fig = corner.corner(
    chain[:,[0,1]],
    labels=['Omega_m', 'sigma8'],
    fig=fig)
