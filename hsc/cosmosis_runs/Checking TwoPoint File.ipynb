# %% [markdown]
# # Checking Two Point File
#
# Checking the SACC/twopoint conversion has kept the right covariance / data vector ordering.

# %%
import twopoint

# %%
filename =  'summary_statistics_hsc_real_published.fits'

# %%
T1 = twopoint.TwoPointFile.from_fits(filename)

# %%
T1.spectra[0]
# Out:
# <Spectrum: xim>

# %%
T1.plots(filename, colormap='viridis', savepdf=True, latex=True, plot_spectrum=True, plot_kernel=True, plot_cov=True, cov_vmin=None, save_pickle=False, load_pickle=False, remove_pickle=True,label_legend ='', blind_yaxis=False)
# Out:
# /Users/Emily/.local/lib/python3.8/site-packages/twopoint/twopoint.py:1003: MatplotlibDeprecationWarning: The 'nonposx' parameter of __init__() has been renamed 'nonpositive' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   ax[j-1][i-1].set_xscale('log', nonposx='clip')
# /Users/Emily/.local/lib/python3.8/site-packages/twopoint/twopoint.py:1004: MatplotlibDeprecationWarning: The 'nonposy' parameter of __init__() has been renamed 'nonpositive' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   ax[j-1][i-1].set_yscale('log', nonposy='clip')
# No handles with labels found to put in legend.
# Saving summary_statistics_hsc_real_published.fits_xim.png
# ...

# %%
# !ls
# Out:
# Checking TwoPoint File.ipynb
# published_matched
# published_nocpsfsys
# summary_statistics_hsc_real_published.fits
# summary_statistics_hsc_real_published.fits_NZ_SOURCE.png
# summary_statistics_hsc_real_published.fits_NZ_SOURCE.png.pdf
# summary_statistics_hsc_real_published.fits_cov.png
# summary_statistics_hsc_real_published.fits_cov.png.pdf
# summary_statistics_hsc_real_published.fits_xim.png
# summary_statistics_hsc_real_published.fits_xim.png.pdf
# summary_statistics_hsc_real_published.fits_xip.png
# summary_statistics_hsc_real_published.fits_xip.png.pdf
# txpipe_matched
# txpipe_publishedcov_matched
# txpipe_publishedcov_nocpsfsys
